# %% [markdown]
# # Session 05
#
# ## Decision Trees

# %%
# import statements
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.datasets import load_digits, load_iris, make_blobs,load_breast_cancer
from sklearn.tree import DecisionTreeClassifier, export_graphviz, DecisionTreeRegressor
from sklearn.metrics import accuracy_score, confusion_matrix, ConfusionMatrixDisplay,f1_score
from sklearn.model_selection import train_test_split
import graphviz


import matplotlib.image as mpimg

# %%
inpDir = os.path.join('..','..','input')
outDir = '../output'
moduleDir = 'machine_learning'



## Basic Parameter


RANDOM_STATE = 24
np.random.seed(RANDOM_STATE)

TEST_SIZE = 0.2

# %%
digits=load_digits()

# %%
#set up the figure

fig = plt.figure(figsize=(12,12)) #figure size in inches

fig.subplots_adjust(left=0,right=1,
                    bottom=0,top=1,
                    hspace=0.05,wspace=0.05
                    )

#plot the dogital :each image is 8 x 8 pixels

for i in range(64):
    ax = fig.add_subplot(8,8,i+1,xticks=[],yticks=[])
    
    ax.imshow(digits.images[i],
              cmap=plt.cm.binary,
              interpolation='nearest')
              
    #label the image with the target  value
    ax.text(0,7,str(digits.target[i]))

# %%
X_train, X_test,y_train,y_test=train_test_split(digits.data,
                                                digits.target, 
                                                random_state=0,
                                            )

clf = DecisionTreeClassifier(max_depth=5)

clf.fit(X_train,y_train)

y_pred = clf.predict(X_test)

cm=confusion_matrix(y_test,y_pred)


disp=ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=digits.target_names)

fig,ax = plt.subplots(figsize = (9,9))

disp.plot(ax=ax,cmap=plt.cm.Blues,colorbar=False);

ax.grid(False)

# %%
#random forest results

fig, axes = plt.subplots(1,3, figsize = (15,8)) # instantiate plt object

for i , max_depth in enumerate([3,5,10]):
    clf=RandomForestClassifier(max_depth=max_depth).fit(X_train,
                                                        y_train)
    y_pred=clf.predict(X_test)

    print("RF: max_depth = {:3d}".format(max_depth), end='|')
    print("F1 score : {: .4f}".format(f1_score(y_test,y_pred,
                                               average='weighted')))
    
    
    cm = confusion_matrix(y_test, y_pred)
    
    disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=digits.target_names)
    
    disp.plot(ax = axes[i], cmap=plt.cm.Blues, colorbar = False)
    axes[i].set_title("RF:max_depth={0}".format(max_depth))
    axes[i].grid(False)
# Out:
# RF: max_depth =   3|F1 score :  0.8558
# RF: max_depth =   5|F1 score :  0.9311
# RF: max_depth =  10|F1 score :  0.9778

# %%
import xgboost as xgb
from sklearn.preprocessing import StandardScaler

from sklearn.model_selection import RandomizedSearchCV

# %%
sc=StandardScaler()
    
X_train=sc.fit_transform(X_train)

X_test = sc.transform(X_test)

# %%
xg_clf = xgb.XGBClassifier(tree_method = 'hist',
                           #tree_method="hist",device="cuda",
                           randome_state=RANDOM_STATE,
                           verbosity=1)
params = {'max_depth':[3,5,6,10,15,20],
          'learing_rate':[0.01,0.1,0.2,0.3],
          'subsample':[0.5,1.0,0.1],
          'colsample_bytree':np.arange(0.4,1.0,0.1),
          'colsample_bylevel':np.arange(0.4,1.0,0.1),
          'n_estimators':[100,500,1000]}

clf=RandomizedSearchCV(estimator=xg_clf,
                       param_distributions=params,
                       scoring='accuracy',
                       n_iter=25,
                       verbose=1)

clf.fit(X_train,y_train)

print("Best parameters : ",clf.best_params_)
print("Best Accuracy : ",clf.best_score_)
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:25:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:25:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:25:57] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:25:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:13] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:15] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:21] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:23] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:26] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:32] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:34] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:39] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:42] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:44] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:46] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:48] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:55] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:26:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:08] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:12] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:18] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:19] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:21] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:24] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:25] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:26] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:31] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:34] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:36] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:38] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:40] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:49] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:51] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:27:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:01] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:03] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:04] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:06] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:08] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:10] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:12] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:14] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:17] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:18] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:18] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:22] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:24] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:26] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:29] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:29] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:32] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:35] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:37] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:39] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:41] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:43] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:45] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:47] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:50] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:53] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:54] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:56] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:58] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:28:59] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:00] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:02] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:05] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:07] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:09] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:11] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:13] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:16] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:18] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:20] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:24] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:25] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:27] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:28] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:30] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /home/hpcap/.local/lib/python3.10/site-packages/xgboost/core.py:160: UserWarning: [20:29:31] WARNING: /workspace/src/learner.cc:742:
# Parameters: { "learing_rate", "randome_state" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# Best parameters :  {'subsample': 0.5, 'n_estimators': 1000, 'max_depth': 15, 'learing_rate': 0.01, 'colsample_bytree': 0.6, 'colsample_bylevel': 0.4}
# Best Accuracy :  0.9703070356601955
