# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns

iris = pd.read_csv("/home/sagar/Desktop/Python/Analytics_&statistic/iris.csv")
exp_sals = pd.read_csv("/home/sagar/Desktop/Python/Analytics_&statistic/Exp_Salaries.csv")

iris['Sepal.Length'].mean()
iris['Sepal.Length'].median()

a = np.array([45, 48, 56, 42, 35, 38, 40])
print(a.mean())
print(np.median(a))

a = np.array([45, 48, 500, 42, 35, 38, 40])
print(a.mean())
print(np.median(a))

exp_sals['Salary'].mean()
males = exp_sals[exp_sals['Gender']=='Male']
fem = exp_sals[exp_sals['Gender']=='Female']
males['Salary'].mean()
fem['Salary'].mean()
# or
exp_sals.groupby('Gender')['Salary'].mean()
exp_sals.groupby('Department')['Salary'].mean()
# Out:
# 43.42857142857143
# 42.0
# 106.85714285714286
# 42.0
# Department
# A    34000.500000
# B    37548.875000
# C    40664.857143
# D    43190.952381
# Name: Salary, dtype: float64

# %%
exp_sals
# Out:
#     Salary  Years_Previous_Experience  Years Employed  Years_Education  \
# 0    32782                          1               0                7
# 1    32920                          3              15                9
# 2    29548                          6               5                1
# 3    39828                          6              18                5
# 4    31528                         11               3                3
# 5    38985                          7              18                9
# 6    41889                         16              22                7
# 7    38791                          4              21                5
# 8    28985                          1               0                4
# 9    24749                          2               6                0
# 10   35467                          6               3                6
# 11   35468                          5               9                4
# ...

# %%
exp_sals.groupby('Gender')['Salary'].quantile([0, 0.25, 0.5, 0.75])
sns.boxplot(data=exp_sals, x='Gender', y='Salary')
# Out:
# <Axes: xlabel='Gender', ylabel='Salary'>

# %%
a = np.array([45,32,53,43,98,46,90,36,75,100,98,87,47,50])

b = np.array([343,364,554,574,464,904,390,367,903,745,569,904,945])


a_var = np.var(a)

a_std = np.std(a)

b_var = np.var(b)

b_std = np.std(b)


print("variance of batsman 'a' :",np.var(a),"\nStandard Deviation of batsman 'a' : ", np.std(a))
print("variance of batsman 'b' :",np.var(b),"\nStandard Deviation of batsman 'b' : ", np.std(b))
# Out:
# variance of batsman 'a' : 605.2040816326531
# Standard Deviation of batsman 'a' :  24.600895951827713
# variance of batsman 'b' : 50395.77514792899
# Standard Deviation of batsman 'b' :  224.49003351580888

# %%
test1 =np.array([43,23,24,34,45,35,32,42,23,12,32])
test2 =np.array([13,25,14,34,35,15,22,32,33,21,12])

marks =pd.DataFrame({'test1'})

# %%
import matplotlib.pyplot as plt
sns.histplot(data= exp_sals, x='Salary')
plt.show()

# %%
sns.histplot(data=exp_sals, x='Number_Supervised')
plt.show()

# %%
cov_matrix = np.corrcoef(exp_sals['Salary'], exp_sals['Years_Education'])

cov_matrix
sns.scatterplot(cov_matrix)
# Out:
# <Axes: >

# %%
cov_mat = np.cov(exp_sals['Salary'], exp_sals['Years_Education'])

cov_mat
sns.scatterplot(cov_mat)
# Out:
# <Axes: >

# %%
# select only the numeric columns

numeric_cols = exp_sals.select_dtypes(include=['float64', 'int64'])

# calculate the correlation matrix

corr_matrix = numeric_cols.corr()


# print the correlation matrix

sns.heatmap(corr_matrix, annot=True)
# Out:
# <Axes: >

# %%
corr_matrix = numeric_cols.corr()

sns.heatmap(corr_matrix, cmap="YlGnBu", annot=True)

plt.xticks(rotation=45)

plt.yticks(rotation=45)

plt.show()

# %%
iris = pd.read_csv("iris.csv")
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
num_cols = exp_sals.columns[ exp_sals.dtypes!= object ]
num_cols
# Out:
# Index(['Salary', 'Years_Previous_Experience', 'Years Employed',
#        'Years_Education', 'Number_Supervised'],
#       dtype='object')

# %%
iris =pd.read_csv("iris.csv")
num_cols =iris.columns[iris.dtypes!=object]
num_cols
num_iris = iris[num_cols]
num_iris.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap(num_iris.corr(), cmap='YlGnBu', annot=True)
plt.xticks(rotation=45)

plt.yticks(rotation=45)

plt.show()

# %%
sns.pairplot(num_iris)

# %%
import pandas as pd 
import numpy as np 
import seaborn as sns
import os
os.chdir("/home/sagar/Desktop/Python/Analytics_&statistic/Datasets")
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pizza =pd.read_csv("pizza.csv")
pizza['Promote'].corr(pizza['Sales'])
# Out:
# 0.9943916799675253

# %%
sns.scatterplot(data=pizza, x='Promote', y='Sales')
plt.show()

# %%
from sklearn.linear_model import LinearRegression
X = pizza[['Promote']]
y = pizza['Sales']
lr = LinearRegression()
lr.fit(X,y)
lr.intercept_,lr.coef_
# Out:
# (5.4858653632529695, array([23.50640302]))
