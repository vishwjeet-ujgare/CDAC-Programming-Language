# %%
import pandas as pd 
import numpy as np 
import os
# iris = pd.read_csv("/home/hpcap/Desktop/Analytics and Statistics/Day_02/iris.csv")
# exp_sals = pd.read_csv("/home/hpcap/Desktop/Analytics and Statistics/Day_02/Exp_Salaries.csv")
os.chdir ("/home/hpcap/Desktop/Analytics and Statistics/Datasets")

iris = pd.read_csv("iris.csv")
exp_sals = pd.read_csv("Exp_Salaries.csv")


import matplotlib.pyplot as plt
import seaborn as sns

# %%
a=np.array([2,4,5,6,7,10,11,17])
b=np.array([23,35,45,57,68,75,84,94])

# %%
np.cov(a,b,ddof=0)
# Out:
# array([[ 19.9375  ,  96.65625 ],
#        [ 96.65625 , 531.109375]])

# %%
np.var(a),np.var(b)
# Out:
# (19.9375, 531.109375)

# %%
a=np.array([2,4,5,6,7,10,11,17])
b=np.array([95,87,82,75,66,54,44,33])
np.cov(a,b,ddof=0)
# Out:
# array([[ 19.9375, -88.625 ],
#        [-88.625 , 416.    ]])

# %%
np.cov(exp_sals["Salary"],exp_sals["Years_Education"],ddof=0)
# Out:
# array([[1.18353291e+08, 2.37390614e+04],
#        [2.37390614e+04, 7.88705104e+00]])

# %% [markdown]
# Correlation

# %%
salary=exp_sals["Salary"]
yoe=exp_sals["Years_Education"]

# %%
np.corrcoef(salary,yoe)
# Out:
# array([[1.        , 0.77699111],
#        [0.77699111, 1.        ]])

# %%
yoe.corr(salary)
# Out:
# 0.7769911080707472

# %%
num_cols = exp_sals.columns[ exp_sals.dtypes!=object]
num_cols
# Out:
# Index(['Salary', 'Years_Previous_Experience', 'Years Employed',
#        'Years_Education', 'Number_Supervised'],
#       dtype='object')

# %%
num_exp_sals=exp_sals[num_cols]
num_exp_sals
# Out:
#     Salary  Years_Previous_Experience  Years Employed  Years_Education  \
# 0    32782                          1               0                7
# 1    32920                          3              15                9
# 2    29548                          6               5                1
# 3    39828                          6              18                5
# 4    31528                         11               3                3
# 5    38985                          7              18                9
# 6    41889                         16              22                7
# 7    38791                          4              21                5
# 8    28985                          1               0                4
# 9    24749                          2               6                0
# 10   35467                          6               3                6
# 11   35468                          5               9                4
# ...

# %%
num_exp_sals.corr()
# Out:
#                              Salary  Years_Previous_Experience  \
# Salary                     1.000000                   0.029354
# Years_Previous_Experience  0.029354                   1.000000
# Years Employed             0.765174                   0.031277
# Years_Education            0.776991                   0.080169
# Number_Supervised          0.523925                   0.216198
#
#                            Years Employed  Years_Education  Number_Supervised
# Salary                           0.765174         0.776991           0.523925
# Years_Previous_Experience        0.031277         0.080169           0.216198
# Years Employed                   1.000000         0.607486           0.345444
# Years_Education                  0.607486         1.000000           0.504609
# Number_Supervised                0.345444         0.504609           1.000000

# %%
# Or
numeric_cols=exp_sals.select_dtypes(include=['float64','int64'])
corr_matrix=numeric_cols.corr()
sns.heatmap(corr_matrix)
# Out:
# <Axes: >

# %%
sns.heatmap( num_exp_sals.corr(),cmap="YlGnBu",annot=True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
iris=pd.read_csv("iris.csv")
iris.head()
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
num_cols=iris.columns[iris.dtypes != object]
num_cols
# Out:
# Index(['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width'], dtype='object')

# %%
num_iris=iris[num_cols]
num_iris
# Out:
#      Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# 0             5.1          3.5           1.4          0.2
# 1             4.9          3.0           1.4          0.2
# 2             4.7          3.2           1.3          0.2
# 3             4.6          3.1           1.5          0.2
# 4             5.0          3.6           1.4          0.2
# ..            ...          ...           ...          ...
# 145           6.7          3.0           5.2          2.3
# 146           6.3          2.5           5.0          1.9
# 147           6.5          3.0           5.2          2.0
# 148           6.2          3.4           5.4          2.3
# 149           5.9          3.0           5.1          1.8
#
# [150 rows x 4 columns]

# %%
num_iris.corr()
# Out:
#               Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# Sepal.Length      1.000000    -0.117570      0.871754     0.817941
# Sepal.Width      -0.117570     1.000000     -0.428440    -0.366126
# Petal.Length      0.871754    -0.428440      1.000000     0.962865
# Petal.Width       0.817941    -0.366126      0.962865     1.000000

# %%
sns.heatmap( num_iris.corr(),cmap="YlGnBu",annot=True)
plt.xticks(rotation=45)
plt.yticks(rotation=45)
plt.show()

# %%
# OR Default

sns.heatmap(num_iris)
# Out:
# <Axes: >

# %%
sns.pairplot(num_iris)
plt.show()
